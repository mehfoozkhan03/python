# %%
print("hello world")
# Out:
# hello world

# %%
name= "mehfooz"
# Out:
# mehfooz

# %%
print(name)
# Out:
# mehfooz

# %%
def sum(a,b):
    return a+b

# %%
ans = sum(10,20)
print(ans,"this is the person " + name)
# Out:
# 30 this is the person mehfooz
